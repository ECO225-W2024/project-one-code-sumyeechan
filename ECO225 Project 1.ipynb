# %%
import pandas as pd

# %%
df = pd.read_csv('2016 School Explorer.csv')
df.head()
# Out:
#   Adjusted Grade New? Other Location Code in LCGMS  \
# 0            NaN  NaN                          NaN
# 1            NaN  NaN                          NaN
# 2            NaN  NaN                          NaN
# 3            NaN  NaN                          NaN
# 4            NaN  NaN                          NaN
#
#                       School Name      SED Code Location Code  District  \
# 0       P.S. 015 ROBERTO CLEMENTE  310100010015        01M015         1
# 1             P.S. 019 ASHER LEVY  310100010019        01M019         1
# 2            P.S. 020 ANNA SILVER  310100010020        01M020         1
# 3  P.S. 034 FRANKLIN D. ROOSEVELT  310100010034        01M034         1
# 4       THE STAR ACADEMY - P.S.63  310100010063        01M063         1
#
#     Latitude  Longitude                    Address (Full)  ...  \
# 0  40.721834 -73.978766   333 E 4TH ST NEW YORK, NY 10009  ...
# 1  40.729892 -73.984231    185 1ST AVE NEW YORK, NY 10003  ...
# ...

# %%
new_df = df[["Economic Need Index", "Student Attendance Rate", "Strong Family-Community Ties %","Percent of Students Chronically Absent", "Collaborative Teachers %"]]
new_df
# Out:
#       Economic Need Index Student Attendance Rate  \
# 0                   0.919                     94%
# 1                   0.641                     92%
# 2                   0.744                     94%
# 3                   0.860                     92%
# 4                   0.730                     93%
# ...                   ...                     ...
# 1267                0.832                     95%
# 1268                0.825                     94%
# 1269                0.724                     95%
# 1270                0.544                     95%
# 1271                0.840                     93%
#
#      Strong Family-Community Ties % Percent of Students Chronically Absent  \
# 0                               85%                                    18%
# 1                               86%                                    30%
# 2                               80%                                    20%
# ...

# %%
new_df.dropna()
# Out:
#       Economic Need Index Student Attendance Rate  \
# 0                   0.919                     94%
# 1                   0.641                     92%
# 2                   0.744                     94%
# 3                   0.860                     92%
# 4                   0.730                     93%
# ...                   ...                     ...
# 1267                0.832                     95%
# 1268                0.825                     94%
# 1269                0.724                     95%
# 1270                0.544                     95%
# 1271                0.840                     93%
#
#      Strong Family-Community Ties % Percent of Students Chronically Absent  \
# 0                               85%                                    18%
# 1                               86%                                    30%
# 2                               80%                                    20%
# ...
